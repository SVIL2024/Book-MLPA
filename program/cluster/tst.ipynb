# %% [markdown]
# ## 案例1

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# 数据集
data = np.array([[10, 2], [15, 3], [20, 4], 
                 [80, 10], [90, 12], [100, 15]])

# 应用K-Means算法
kmeans = KMeans(n_clusters=2, random_state=42)
labels = kmeans.fit_predict(data)

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.figure(figsize=(6, 4))
# 可视化结果
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', s=50)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
            c='red', marker='x', s=200, label='原型点')
plt.xlabel("年度消费(千元)")
plt.ylabel("周期 (次/月)")
plt.legend()
plt.grid()
plt.title("消费者分析")
plt.show()
# Out:
# C:\Users\limax\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\limax\AppData\Roaming\Python\Python38\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# ## 案例2-

# %%
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# 数据集
data = np.array([[1, 2], [1.5, 2.5], [2, 3], 
                 [10, 15], [11, 16], [50, 70]])

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.figure(figsize=(6, 4))
# 应用DBSCAN算法
dbscan = DBSCAN(eps=5, min_samples=2)
labels = dbscan.fit_predict(data)

# 可视化结果
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', s=50)
plt.xlabel("交易数量（千元）")
plt.ylabel("时间间隔 (小时)")
plt.title("使用DBSCAN进行异常检测")
plt.grid()
plt.show()

# %% [markdown]
# ## 案例3

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# 数据集
data = [[0.1, 0.2], [0.15, 0.25], [0.2, 0.3], 
        [0.8, 0.9], [0.85, 0.95], [0.9, 1.0]]

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.figure(figsize=(6, 4))
# 计算层次聚类的链接矩阵
Z = linkage(data, method='average')

# 绘制树状图
dendrogram(Z)
plt.title("层次化聚类树状图")
plt.xlabel("数据点")
plt.ylabel("距离")
plt.grid()
plt.show()
